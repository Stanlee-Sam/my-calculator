# %% [markdown]
# <a href="https://colab.research.google.com/github/Stanlee-Sam/my-calculator/blob/main/Number_Guessing_Game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

def guess_the_number():
  number = random.randint(1,100)
  print('Welcome to the Guess the Number game!')

  #print(number)

  guess = int(input("I'm thinking of a number between 1 and 100. Can you guess what it is? "))

  while guess != number:
    if guess < number:
      print('Your guess is too low. Guess again.')
    else:
      print('Your guess is too high. Guess again.')

    guess = int(input('Enter your guess: '))

  print('Congratulations! You guessed the number correctly!')

guess_the_number()
# Out:
# Welcome to the Guess the Number game!
# I'm thinking of a number between 1 and 100. Can you guess what it is? 8
# Your guess is too low. Guess again.
# Enter your guess: 45
# Your guess is too low. Guess again.
# Enter your guess: 78
# Your guess is too low. Guess again.
# Enter your guess: 98
# Your guess is too high. Guess again.
# Enter your guess: 88
# Your guess is too high. Guess again.
# Enter your guess: 85
# Your guess is too low. Guess again.
# Enter your guess: 86
# Congratulations! You guessed the number correctly!
